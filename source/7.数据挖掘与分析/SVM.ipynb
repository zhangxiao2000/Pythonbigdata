# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets.samples_generator import make_blobs
X,y=make_blobs(n_samples=50,centers=2,random_state=0,cluster_std=0.60)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='viridis')

# %%
import numpy as np
xfit=np.linspace(-1,3.5)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='viridis')
plt.plot([0.6],[2.1],'x',color="red",markeredgewidth=2,markersize=10)
for m,b in [(1,0.6),(0.5,1.5),(-0.2,3)]:
    plt.plot(xfit,m*xfit+b,'-k')
    
plt.xlim(-1,3.5)
# Out:
# (-1, 3.5)

# %%
import numpy as np
xfit=np.linspace(-1,3.5)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='viridis')
plt.plot([0.6],[2.1],'x',color="red",markeredgewidth=2,markersize=10)
for m,b in [(1,0.6),(0.5,1.5),(-0.2,3)]:
    plt.plot(xfit,m*xfit+b,color="gray",alpha=0.5,linewidth=10)
for m,b in [(1,0.6),(0.5,1.5),(-0.2,3)]:
    plt.plot(xfit,m*xfit+b,'-k')
    
plt.xlim(-1,3.5)
# Out:
# (-1, 3.5)

# %%
import numpy as np
xfit=np.linspace(-1,3.5)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='viridis')
plt.plot([0.6],[2.1],'x',color="red",markeredgewidth=2,markersize=10)
for m,b in [(1,0.6),(0.5,1.5),(-0.2,3)]:
    plt.plot(xfit,m*xfit+b,color="gray",alpha=0.5,linewidth=10)
m,b=(0.5,1.6)
plt.plot(xfit,m*xfit+b,'-k')
    
plt.xlim(-1,3.5)
# Out:
# (-1, 3.5)

# %%
import numpy as np
xfit=np.linspace(-1,3.5)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='viridis')
m,b=(0.167,3.041)
plt.plot(xfit,m*xfit+b,'--')
m,b=(0.167,1.625)
plt.plot(xfit,m*xfit+b,'--')    
m,b=(0.167,2.333)
plt.plot(xfit,m*xfit+b,'-k')    
plt.xlim(-1,3.5)
# Out:
# (-1, 3.5)

# %%
import pandas as pd
df=pd.DataFrame(X)
df.columns=['x','y']
print(df[df['y']>2.5].sort_values(by='y').head(2))
print(df[df['y']<2.5].sort_values(by='y').tail(2))
# Out:
#            x         y
# 18  0.443599  3.115309
# 25  2.338123  3.431168
#            x         y
# 7   2.061568  1.969186
# 46  2.948219  2.035197

# %%
import pandas as pd
import numpy as np

titanic_df = pd.read_csv('data/titanic2.csv')

# %%
#选取参与训练和预测的特征与目标
features = titanic_df[['Pclass', 'Age', 'Fare', 'Cabin_cat', 'Sex_female', 'Sex_male', 'Embarked_cat']]
target = titanic_df['Survived']

#分离数据集
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=33)

#从sklearn中引入支持向量机分类（SVC）
from sklearn.svm import SVC
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=['died', 'survived']))
# Out:
#              precision    recall  f1-score   support
#
#        died       0.83      0.86      0.85       164
#    survived       0.77      0.73      0.75       104
#
# avg / total       0.81      0.81      0.81       268
